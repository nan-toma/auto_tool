# %%
import csv
import copy
import pandas as pd
import codecs

# %% [markdown]
# ### ME2

# %%
me2_csv = pd.read_csv("C:\\Users\\toman01\\Downloads\\me2_all.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-733d7e102c93> in <module>
# ----> 1 me2_csv = pd.read_csv("C:\\Users\\toman01\\Downloads\\me2_all.csv")
#
# c:\pythondev\miniconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# c:\pythondev\miniconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# c:\pythondev\miniconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\pythondev\miniconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# c:\pythondev\miniconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x83 in position 0: invalid start byte

# %%
pd.set_option('display.max_columns', 150)

# %%
with codecs.open("C:\\Users\\toman01\\Downloads\\me2_all.csv", "r", "Shift-JIS", "ignore") as file:
    df = pd.read_table(file, delimiter=",")
# Out:
# c:\pythondev\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (12,13,24,26,42,45,46,47,50,51,62,83,116,117,121,124,125,127,128,129,130,132,133,134,136,137,139,141,142,145,146) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
backup_D_number_list = list(df["D#（冗長）"].dropna(how="all"))

# %%
df[(df["カスタマID（冗長）"].isnull()) & (df["D#（冗長）"].str.contains('D'))]["D#（冗長）"]
# Out:
# Series([], Name: D#（冗長）, dtype: object)

# %%
true_count = df[~df["契約番号D#"].isin(backup_D_number_list)]["契約番号D#"].isin(["D417650095"])

# %%
true_count.sum()
# Out:
# 0

# %%
df[~df["契約番号D#"].isin(backup_D_number_list)]["契約番号D#"].to_csv("me2_not_backup_list.csv")
# Out:
# c:\pythondev\miniconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### SVPN

# %%
pd.set_option('display.max_columns', 150)

# %%
with codecs.open("C://Users//toman01//Downloads/me2_all (3).csv", "r", "Shift-JIS", "ignore") as file:
    df = pd.read_table(file, delimiter=",")
# Out:
# c:\pythondev\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (6,7,11,14,21,23,24,26,27,35,46,47,50,51,58,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
backup_D_number_list = list(df["D#（冗長）"].dropna(how="all"))

# %%
df[~df["契約番号D#"].isin(backup_D_number_list)]["契約番号D#"].to_csv("svpn_not_backup_list.csv")
# Out:
# c:\pythondev\miniconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
with open('C://Users//toman01//Desktop//development//me2_not_backup_list.csv') as f:
    reader = csv.reader(f)
    me2_backup_list = [row[1] for row in reader]

# %%
me2_backup_list
# Out:
# ['D300140986',
#  'D300140987',
#  'D300159984',
#  'D300159988',
#  'D300159996',
#  'D300160001',
#  'D300032142',
#  'D300032143',
#  'D300032272',
#  'D300032744',
#  'D300120957',
#  'D300120954',
#  'D300120973',
#  'D300024019',
#  'D300029292',
#  'D300029293',
#  'D300029295',
#  'D300029297',
#  'D300032118',
#  'D300102764',
#  'D300102765',
#  'D300102766',
#  'D300102767',
#  'D300102768',
#  'D300102769',
#  'D300102770',
#  'D300102944',
#  'D300105322',
#  'D300106413',
#  'D300109303',
#  'D300109313',
#  'D300109619',
#  'D300110581',
#  'D300112310',
#  'D300113008',
#  'D300113181',
#  'D300113204',
#  'D300113375',
#  'D300113722',
#  'D300114200',
#  'D300114430',
#  'D300115961',
#  'D300116068',
#  'D300117003',
#  'D300119036',
#  'D300023899',
#  'D300023902',
#  'D300023903',
#  'D300023905',
#  'D300023906',
#  'D300023907',
#  'D300023908',
#  'D300023911',
#  'D300023912',
#  'D300023913',
#  'D300023914',
#  'D300023915',
#  'D300023916',
#  'D300023917',
#  'D300023922',
#  'D300023988',
#  'D300023990',
#  'D300023992',
#  'D300023996',
#  'D300023998',
#  'D300024001',
#  'D300024002',
#  'D300024003',
#  'D300024005',
#  'D300024015',
#  'D300024017',
#  'D300024018',
#  'D300024078',
#  'D300024115',
#  'D300024116',
#  'D300024117',
#  'D300024118',
#  'D300024119',
#  'D300024122',
#  'D300024123',
#  'D300024124',
#  'D300024125',
#  'D300024130',
#  'D300024131',
#  'D300024132',
#  'D300024133',
#  'D300024135',
#  'D300024138',
#  'D300024139',
#  'D300024140',
#  'D300024141',
#  'D300024143',
#  'D300024144',
#  'D300024145',
#  'D300024148',
#  'D300024149',
#  'D300024151',
#  'D300024152',
#  'D300024154',
#  'D300024155',
#  'D300024156',
#  'D300024157',
#  'D300024724',
#  'D300024725',
#  'D300024726',
#  'D300024727',
#  'D300024728',
#  'D300024729',
#  'D300024730',
#  'D300024731',
#  'D300024732',
#  'D300024734',
#  'D300024736',
#  'D300024737',
#  'D300024738',
#  'D300024741',
#  'D300024942',
#  'D300024943',
#  'D300025343',
#  'D300025605',
#  'D300025606',
#  'D300025679',
#  'D300025687',
#  'D300025688',
#  'D300025689',
#  'D300026407',
#  'D300125444',
#  'D300127242',
#  'D300023947',
#  'D300023957',
#  'D300023948',
#  'D300023962',
#  'D300107793',
#  'D300023949',
#  'D300023963',
#  'D300023950',
#  'D300023956',
#  'D300023951',
#  'D300023959',
#  'D300023952',
#  'D300023958',
#  'D300023953',
#  'D300023960',
#  'D300023946',
#  'D300023954',
#  'D300023955',
#  'D300023984',
#  'D300032819',
#  'D300024709',
#  'D300024713',
#  'D300024716',
#  'D300024717',
#  'D300025692',
#  'D300025699',
#  'D300025700',
#  'D300025653',
#  'D300025658',
#  'D300025693',
#  'D300103896',
#  'D300024813',
#  'D300024814',
#  'D300024817',
#  'D300024819',
#  'D300024826',
#  'D300024827',
#  'D300024828',
#  'D300024829',
#  'D300024830',
#  'D300024832',
#  'D300024833',
#  'D300026598',
#  'D300024756',
#  'D300024757',
#  'D300024755',
#  'D300026193',
#  'D300026969',
#  'D300027856',
#  'D300027876',
#  'D300028900',
#  'D300029102',
#  'D300029918',
#  'D300032270',
#  'D300103617',
#  'D300103629',
#  'D300103631',
#  'D300103635',
#  'D300103636',
#  'D300103747',
#  'D300104217',
#  'D300104458',
#  'D300104469',
#  'D300105752',
#  'D300106625',
#  'D300108094',
#  'D300109178',
#  'D300109179',
#  'D300109993',
#  'D300110610',
#  'D300110932',
#  'D300111199',
#  'D300111912',
#  'D300111927',
#  'D300113023',
#  'D300115474',
#  'D300116908',
#  'D300024710',
#  'D300024711',
#  'D300024715',
#  'D300024758',
#  'D300102594',
#  'D300102595',
#  'D300102596',
#  'D300102597',
#  'D300102598',
#  'D300102599',
#  'D300102600',
#  'D300102601',
#  'D300106136',
#  'D300106137',
#  'D300106139',
#  'D300106143',
#  'D300107404',
#  'D300107455',
#  'D300107456',
#  'D300107734',
#  'D300107737',
#  'D300107848',
#  'D300108275',
#  'D300108907',
#  'D300108909',
#  'D300108910',
#  'D300108912',
#  'D300108913',
#  'D300108915',
#  'D300108916',
#  'D300108917',
#  'D300109383',
#  'D300109384',
#  'D300109385',
#  'D300109386',
#  'D300109387',
#  'D300109933',
#  'D300110302',
#  'D300112100',
#  'D300112188',
#  'D300112450',
#  'D300113828',
#  'D300114174',
#  'D300114175',
#  'D300114432',
#  'D300115293',
#  'D300115305',
#  'D300116799',
#  'D300116893',
#  'D300117258',
#  'D300117707',
#  'D300117708',
#  'D300119219',
#  'D300024944',
#  'D300024945',
#  'D300025506',
#  'D300025515',
#  'D300025516',
#  'D300025517',
#  'D300025518',
#  'D300025519',
#  'D300025520',
#  'D300025521',
#  'D300025522',
#  'D300025523',
#  'D300025524',
#  'D300025621',
#  'D300025622',
#  'D300025623',
#  'D300025624',
#  'D300025626',
#  'D300025627',
#  'D300025628',
#  'D300025629',
#  'D300025630',
#  'D300025631',
#  'D300025632',
#  'D300025633',
#  'D300127703',
#  'D300128071',
#  'D300127438',
#  'D300128525',
#  'D300030390',
#  'D300024823',
#  'D300024834',
#  'D300024836',
#  'D300025307',
#  'D300025941',
#  'D300025944',
#  'D300025945',
#  'D300025946',
#  'D300025947',
#  'D300025948',
#  'D300025985',
#  'D300025987',
#  'D300025990',
#  'D300025991',
#  'D300026009',
#  'D300026010',
#  'D300026011',
#  'D300026012',
#  'D300026014',
#  'D300026015',
#  'D300026016',
#  'D300026017',
#  'D300026019',
#  'D300026423',
#  'D300026424',
#  'D300026426',
#  'D300026427',
#  'D300026428',
#  'D300026439',
#  'D300026440',
#  'D300026441',
#  'D300026442',
#  'D300026443',
#  'D300026444',
#  'D300026445',
#  'D300026446',
#  'D300026447',
#  'D300026448',
#  'D300026449',
#  'D300026450',
#  'D300026451',
#  'D300026452',
#  'D300026453',
#  'D300026544',
#  'D300026546',
#  'D300026549',
#  'D300026554',
#  'D300026664',
#  'D300026665',
#  'D300026666',
#  'D300026668',
#  'D300026669',
#  'D300026670',
#  'D300026671',
#  'D300026673',
#  'D300026675',
#  'D300026676',
#  'D300026677',
#  'D300026679',
#  'D300026680',
#  'D300026681',
#  'D300026682',
#  'D300026683',
#  'D300026684',
#  'D300026685',
#  'D300026762',
#  'D300026767',
#  'D300026770',
#  'D300026771',
#  'D300026807',
#  'D300026816',
#  'D300026820',
#  'D300026822',
#  'D300027339',
#  'D300027348',
#  'D300027349',
#  'D300027351',
#  'D300027353',
#  'D300027354',
#  'D300027355',
#  'D300027356',
#  'D300027357',
#  'D300027358',
#  'D300027359',
#  'D300027360',
#  'D300027361',
#  'D300027363',
#  'D300027820',
#  'D300027823',
#  'D300028006',
#  'D300028059',
#  'D300028061',
#  'D300028538',
#  'D300028807',
#  'D300029082',
#  'D300029342',
#  'D300029376',
#  'D300029416',
#  'D300029940',
#  'D300030195',
#  'D300030196',
#  'D300030197',
#  'D300030201',
#  'D300031524',
#  'D300031639',
#  'D300031731',
#  'D300031906',
#  'D300031907',
#  'D300032024',
#  'D300032307',
#  'D300032896',
#  'D300103203',
#  'D300107366',
#  'D300110649',
#  'D300111515',
#  'D300111518',
#  'D300111519',
#  'D300111581',
#  'D300111582',
#  'D300111657',
#  'D300111850',
#  'D300111882',
#  'D300113159',
#  'D300113707',
#  'D300114318',
#  'D300114697',
#  'D300114842',
#  'ME06042402IC01',
#  'ME06042402IC02',
#  'D300024838',
#  'D300026551',
#  'D300028008',
#  'D300028056',
#  'D300029084',
#  'D300032392',
#  'D300102727',
#  'D300102802',
#  'D300105183',
#  'D300105268',
#  'D300107233',
#  'D300107443',
#  'D300109213',
#  'D300110406',
#  'D300110998',
#  'D300111196',
#  'D300111566',
#  'D300111849',
#  'D300112660',
#  'D300114896',
#  'D300114897',
#  'D300115335',
#  'D300117121',
#  'D300026578',
#  'D300026581',
#  'D300026602',
#  'D300026603',
#  'D300026604',
#  'D300026607',
#  'D300026610',
#  'D300026612',
#  'D300026615',
#  'D300026618',
#  'D300026619',
#  'D300026628',
#  'D300026637',
#  'D300026638',
#  'D300026641',
#  'D300026642',
#  'D300026644',
#  'D300026655',
#  'D300026663',
#  'D300026695',
#  'D300026697',
#  'D300026710',
#  'D300026712',
#  'D300026738',
#  'D300026739',
#  'D300026740',
#  'D300026938',
#  'D300026941',
#  'D300026945',
#  'D300026947',
#  'D300027135',
#  'D300027225',
#  'D300027232',
#  'D300027346',
#  'D300027453',
#  'D300027612',
#  'D300027764',
#  'D300027827',
#  'D300028229',
#  'D300028230',
#  'D300028288',
#  'D300028786',
#  'D300031866',
#  'D300120610',
#  'D300123146',
#  'D300027306',
#  'D300028011',
#  'D300029066',
#  'D300029097',
#  'D300029715',
#  'D300029717',
#  'D300103401',
#  'D300104021',
#  'D300105241',
#  'D300114419',
#  'D300118074',
#  'D300118605',
#  'ME06042502IC01',
#  'ME06042502IC02',
#  'D300026580',
#  'D300026600',
#  'D300026601',
#  'D300026608',
#  'D300026609',
#  'D300026611',
#  'D300026613',
#  'D300026614',
#  'D300026616',
#  'D300026617',
#  'D300026621',
#  'D300026622',
#  'D300026623',
#  'D300026624',
#  'D300026626',
#  'D300026627',
#  'D300026636',
#  'D300026639',
#  'D300026640',
#  'D300026643',
#  'D300026646',
#  'D300026647',
#  'D300026648',
#  'D300026649',
#  'D300026650',
#  'D300026660',
#  'D300026661',
#  'D300026662',
#  'D300026694',
#  'D300026696',
#  'D300026698',
#  'D300026699',
#  'D300026700',
#  'D300026701',
#  'D300026702',
#  'D300026703',
#  'D300026704',
#  'D300026705',
#  'D300026706',
#  'D300026707',
#  'D300026708',
#  'D300026713',
#  'D300026715',
#  'D300026717',
#  'D300026741',
#  'D300026742',
#  'D300026792',
#  'D300026856',
#  'D300026862',
#  'D300026950',
#  'D300026980',
#  'D300027000',
#  'D300027001',
#  'D300027002',
#  'D300027003',
#  'D300027009',
#  'D300027014',
#  'D300027126',
#  'D300027130',
#  'D300027217',
#  'D300027228',
#  'D300027236',
#  'D300027268',
#  'D300027270',
#  'D300027273',
#  'D300027277',
#  'D300027284',
#  'D300027285',
#  'D300027450',
#  'D300027456',
#  'D300027551',
#  'D300027560',
#  'D300027607',
#  'D300027609',
#  'D300027770',
#  'D300027775',
#  'D300027800',
#  'D300027837',
#  'D300027892',
#  'D300027909',
#  'D300028461',
#  'D300028785',
#  'D300029128',
#  'D300029387',
#  'D300029388',
#  'D300029484',
#  'D300029485',
#  'D300032035',
#  'D300032431',
#  'D300120181',
#  'D300028739',
#  'D300030885',
#  'D300031027',
#  'D300031551',
#  'D300032144',
#  'D300032197',
#  'D300032455',
#  'D300032476',
#  'D300032616',
#  'D300032725',
#  'D300032868',
#  'D300102277',
#  'D300103444',
#  'D300103658',
#  'D300104049',
#  'D300104098',
#  'D300105148',
#  'D300106141',
#  'D300106436',
#  'D300111122',
#  'D300111743',
#  'D300112658',
#  'D300116436',
#  'D300026406',
#  'D300026527',
#  'D300025017',
#  'D300025020',
#  'D300102397',
#  'D300103465',
#  'D300103466',
#  'D300103467',
#  'D300115486',
#  'D300116299',
#  'ME06051102KS01',
#  'D300029333',
#  'D300029335',
#  'D300029337',
#  'D300029339',
#  'D300029340',
#  'D300102400',
#  'D300102406',
#  'K300102408',
#  'D300103468',
#  'D300103469',
#  'D300103470',
#  'D300115488',
#  'D300116301',
#  'D300025358',
#  'D300025489',
#  'D300025906',
#  'D300028516',
#  'D300112284',
#  'D300025351',
#  'D300025736',
#  'D300025737',
#  'D300025738',
#  'D300025778',
#  'D300025783',
#  'D300025890',
#  'D300025892',
#  'D300025893',
#  'D300026216',
#  'D300120152',
#  'ME06052201KS01',
#  'ME06052201IC01',
#  'ME06052201IC02',
#  'D300025895',
#  'D300025896',
#  'D300025216',
#  'D300025219',
#  'D300026507',
#  'D300029503',
#  'D300026362',
#  'D300026364',
#  'D300026365',
#  'D300026367',
#  'D300026368',
#  'D300026371',
#  'D300026373',
#  'D300026375',
#  'D300026378',
#  'D300032176',
#  'D300032179',
#  'D300032180',
#  'D300032181',
#  'D300032182',
#  'D300032185',
#  'D300032187',
#  'D300032379',
#  'D300108604',
#  'D300108935',
#  'D300110671',
#  'D300110956',
#  'D300110957',
#  'D300112878',
#  'D300113094',
#  'D300113481',
#  'D300114331',
#  'D300116749',
#  'D300025908',
#  'D300025909',
#  'D300025910',
#  'D300025911',
#  'D300025912',
#  'D300025914',
#  'D300025937',
#  'D300025938',
#  'D300111984',
#  'D300025352',
#  'D300025353',
#  'D300025492',
#  'D300025498',
#  'D300025499',
#  'D300026556',
#  'D300025493',
#  'D300026832',
#  'D300028023',
#  'D300028136',
#  'D300028150',
#  'D300028151',
#  'D300028152',
#  'D300028153',
#  'D300028154',
#  'D300028155',
#  'D300028156',
#  'D300028157',
#  'D300028158',
#  'D300028159',
#  'D300028160',
#  'D300028161',
#  'D300028162',
#  'D300028163',
#  'D300028164',
#  'D300028165',
#  'D300028166',
#  'D300028167',
#  'D300028168',
#  'D300028169',
#  'D300028170',
#  'D300028171',
#  'D300028172',
#  'D300028174',
#  'D300028175',
#  'D300028355',
#  'D300028356',
#  'D300028357',
#  'D300028358',
#  'D300028360',
#  'D300028362',
#  'D300028363',
#  'D300028364',
#  'D300028367',
#  'D300028368',
#  'D300028369',
#  'D300028370',
#  'D300028371',
#  'D300028372',
#  'D300028373',
#  'D300028374',
#  'D300028375',
#  'D300028376',
#  'D300028378',
#  'D300028390',
#  'D300028392',
#  'D300028393',
#  'D300028395',
#  'D300028399',
#  'D300028402',
#  'D300028403',
#  'D300028404',
#  'D300028405',
#  'D300028406',
#  'D300028412',
#  'D300028416',
#  'D300028422',
#  'D300028424',
#  'D300028426',
#  'D300028427',
#  'D300028428',
#  'D300028429',
#  'D300028430',
#  'D300028431',
#  'D300028432',
#  'D300028433',
#  'D300028434',
#  'D300028435',
#  'D300028436',
#  'D300028437',
#  'D300028438',
#  'D300028439',
#  'D300028440',
#  'D300028441',
#  'D300028442',
#  'D300028443',
#  'D300028444',
#  'D300028445',
#  'D300028446',
#  'D300028447',
#  'D300028448',
#  'D300028449',
#  'D300028450',
#  'D300028451',
#  'D300028452',
#  'D300028453',
#  'D300028454',
#  'D300028455',
#  'D300028456',
#  'D300028457',
#  'D300028518',
#  'D300028678',
#  'D300028679',
#  'D300028681',
#  'D300028682',
#  'D300028857',
#  'D300028858',
#  'D300028859',
#  'D300028860',
#  'D300028861',
#  'D300028862',
#  'D300028863',
#  'D300028864',
#  'D300028865',
#  'D300028866',
#  'D300028867',
#  'D300028868',
#  'D300028869',
#  'D300028870',
#  'D300028871',
#  'D300028872',
#  'D300028873',
#  'D300028874',
#  'D300028875',
#  'D300029131',
#  'D300029132',
#  'D300029135',
#  'D300029137',
#  'D300029138',
#  'D300029139',
#  'D300029141',
#  'D300029142',
#  'D300029143',
#  'D300029145',
#  'D300029147',
#  'D300029151',
#  'D300029154',
#  'D300029158',
#  'D300029160',
#  'D300029162',
#  'D300029165',
#  'D300029167',
#  'D300029170',
#  'D300029176',
#  'D300029180',
#  'D300029181',
#  'D300029184',
#  'D300029185',
#  'D300029186',
#  'D300029187',
#  'D300029188',
#  'D300029189',
#  'D300029190',
#  'D300029191',
#  'D300029192',
#  'D300029193',
#  'D300029495',
#  'D300029802',
#  'D300031722',
#  'D300031853',
#  'D300031925',
#  'D300031926',
#  'D300031999',
#  'D300032276',
#  'D300032402',
#  'D300103398',
#  'D300105726',
#  'D300107578',
#  'D300107871',
#  'D300111200',
#  'D300111911',
#  'D300112126',
#  'D300112127',
#  'D300115061',
#  'D300115197',
#  'D300115710',
#  'D300115727',
#  'D300116841',
#  'D300117979',
#  'ME06053002IC01',
#  'ME06053002IC02',
#  'D300025494',
#  'D300025495',
#  'D300120143',
#  'D300120141',
#  'D300120939',
#  'D300123168',
#  'D300115191',
#  'D300118321',
#  'D300025286',
#  'D300025292',
#  'D300029294',
#  'D300029942',
#  'D300103394',
#  'D300104338',
#  'D300106518',
#  'D300106530',
#  'D300116538',
#  'D300116850',
#  'ME06061301IC01',
#  'ME06061301IC02',
#  'D300025980',
#  'D300025983',
#  'D300026686',
#  'D300026687',
#  'D300026688',
#  'D300026689',
#  'D300026690',
#  'D300027819',
#  'D300026316',
#  'D300028541',
#  'D300028542',
#  'D300028543',
#  'D300030513',
#  'D300031817',
#  'D300032872',
#  'D300102335',
#  'D300102604',
#  'D300102605',
#  'D300102606',
#  'D300102877',
#  'D300102889',
#  'D300104309',
#  'D300105125',
#  'D300106321',
#  'D300107219',
#  'D300108066',
#  'D300108461',
#  'D300109925',
#  'D300111352',
#  'D300111565',
#  'D300113560',
#  'D300116355',
#  'D300118718',
#  'ME06061302IC01',
#  'ME06061302IC02',
#  'D300025735',
#  'D300025996',
#  'D300026002',
#  'D300032662',
#  'D300026387',
#  'D300026388',
#  'D300026389',
#  'D300026390',
#  'D300026401',
#  'D300026402',
#  'D300026405',
#  'D300031523',
#  'D300102457',
#  'D300102854',
#  'D300103648',
#  'D300103649',
#  'D300108425',
#  'D300108557',
#  'D300115928',
#  'D300118501',
#  'D300026396',
#  'D300026399',
#  'D300026400',
#  'D300026403',
#  'D300026404',
#  'D300026408',
#  'D300026410',
#  'D300026412',
#  'D300026413',
#  'D300026414',
#  'D300026415',
#  'D300026324',
#  'D300028802',
#  'D300103385',
#  'D300111214',
#  'D300111394',
#  'D300026323',
#  'D300026325',
#  'D300026328',
#  'D300026592',
#  'D300125901',
#  'D300029343',
#  'D300103162',
#  'D300103846',
#  'D300103847',
#  'D300103849',
#  'D300117770',
#  'ME06062801IC01',
#  'ME06062801IC02',
#  'D300026726',
#  'D300026727',
#  'D300027513',
#  'D300027519',
#  'D300028366',
#  'D300026215',
#  'D300026339',
#  'D300028902',
#  'D300029100',
#  'D300112221',
#  'D300114197',
#  'D300116997',
#  'ME06063001IC01',
#  'ME06063001IC02',
#  'D300026208',
#  'D300026212',
#  'D300026313',
#  'D300026314',
#  ...]

# %%
host_unique_list = []
for row in csv_list[1:]:
    host_unique_list.append(row[4])

host_list = list(set(host_unique_list))

# %%
for n,row in enumerate(csv_list):
    if host_list[0] in row:
        print(n,row)
        last_state = row
# Out:
# 39 ['2020/09/07 03:58:09.658', 'down', 'H000042401', 'NTT西有田', 'SA520-057AN-01', '3/3', 'SA520-057PT-01[1/2]', 'br10', '福岡東', 'FO008-192ZR-01', 'HundredGigE0/7/0/0.101', 'SA520-003PTB-01[9/1] ICHIGO-1357']
# 172 ['2020/09/07 12:13:16.860', 'up', 'H000042401', 'NTT西有田', 'SA520-057AN-01', '3/3', 'SA520-057PT-01[1/2]', 'br10', '福岡東', 'FO008-192ZR-01', 'HundredGigE0/7/0/0.101', 'SA520-003PTB-01[9/1] ICHIGO-1357']
# 189 ['2020/09/07 12:14:29.991', 'up', 'H000042401', 'NTT西有田', 'SA520-057AN-01', '3/3', 'SA520-057PT-01[1/2]', 'br10', '福岡東', 'FO008-192ZR-01', 'HundredGigE0/7/0/0.101', 'SA520-003PTB-01[9/1] ICHIGO-1357']

# %%
csv_list_copy = copy.copy(csv_list)

# %%
csv_list_copy[189][1] = "down"

# %%
if last_state[1] == "up":
    # print(last_state[4] + " is" + " OK")
    pass
else:
    print(last_state[4] + "is" + "NG")
    NG_list.append(last_state[4])
# Out:
# SA520-057AN-01 is OK

# %%
NG_list = []
for host_name in host_list:
    for row in csv_list_copy:
        if host_name in row:
            last_state = row
    if last_state[1] == "up":
        print(last_state[4] + " is" + " OK")
        pass
    else:
        print(last_state[4] + " is" + " NG")
        NG_list.append(last_state[4])
# Out:
# SA520-057AN-01 is NG
# SA520-012AN-01 is OK
# SA520-004AN-02 is OK
# SA520-019AN-02 is OK
# SA520-029AN-01 is OK
# SA520-023AN-02 is OK
# NG510-008AN-01 is OK
# SA520-005AN-02 is OK
# NG510-004AN-01 is OK
# SA520-004AR-21 is OK
# SA520-054AN-02 is OK
# SA520-054AN-01 is OK
# SA520-064AN-01 is OK
# SA520-002AN-01 is OK
# SA520-003AN-01 is OK
# SA520-044AN-01 is OK
# SA520-004AN-01 is OK
# NG510-050AN-01 is OK
# NG510-001AN-03 is OK
# NG510-005AN-01 is OK
# SA520-011AN-01 is OK
# SA520-069AN-02 is OK
# SA520-013AN-01 is OK
# SA520-056AN-01 is OK
# SA520-019AN-01 is OK
# SA520-067AN-01 is OK
# SA520-005AN-01 is OK
# SA520-007AN-01 is OK
# SA520-010AN-01 is OK
# SA520-034AN-01 is OK
# SA520-062AN-01 is OK
# SA520-061AN-01 is OK
# SA520-034AN-02 is OK
# NG510-003AN-02 is OK
# SA520-003AN-02 is OK
# NG510-008AN-02 is OK
# SA520-003AN-03 is OK
# SA520-004AN-03 is OK
# SA520-001AN-01 is OK
# SA520-030AN-01 is OK
# SA520-065AN-01 is OK
# SA520-035AN-01 is OK
# SA520-059AN-01 is OK
# NG510-003AN-01 is OK
# SA520-058AN-01 is OK
# NG510-007AN-01 is OK
# SA520-012AN-02 is OK
# SA520-028AN-01 is OK
# SA520-012AN-03 is OK
# NG510-569AN-01 is OK
# SA520-023AN-01 is OK
# SA520-042AN-01 is OK

# %%
NG_list
# Out:
# ['SA520-057AN-01']

# %%
f.close()

# %%
43/8
# Out:
# 5.375

# %%
8/43
# Out:
# 0.18604651162790697

# %%
60000*2000/10
# Out:
# 12000000.0

# %%
50000*1000/9
# Out:
# 5555555.555555556

# %%
40000*3000/8
# Out:
# 15000000.0

# %%
(12000000.0+5555555.5 + 15000000.0) / 3
# Out:
# 10851851.833333334

# %%
10 * 0.4
# Out:
# 4.0

# %%
15*0.1
# Out:
# 1.5

# %%
50*0.05
# Out:
# 2.5

# %%
3.5*3
# Out:
# 10.5

# %%
10.5+35
# Out:
# 45.5

# %%
45.5*0.05*2
# Out:
# 4.55

# %%
240*0.2
# Out:
# 48.0

# %%
240*0.3
# Out:
# 72.0

# %%
240-72
# Out:
# 168

# %%
(0.9+0.9+0.1+0.1+0.1) /5
# Out:
# 0.42000000000000004

# %%
0.1*0.1*0.1*0.1*0.9
# Out:
# 9.000000000000003e-05

# %%
(20+28+14+27+26+16+16)/7
# Out:
# 21.0

# %%
(258+244+264+201+256+320)/6
# Out:
# 257.1666666666667
